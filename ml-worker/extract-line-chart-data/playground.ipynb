# %%
from plextract import extract

extract(input_dir="examples/input", output_dir="examples/output", backend="modal")
# Out:
# 2025-11-26 10:53:48,533 | INFO | plextract | Running plextract remotely on modal...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from plextract import extract
# ----> 3 extract(input_dir="examples/input", output_dir="examples/output", backend="modal")
#
# File ~/extract-line-chart-data/src/plextract/extract.py:14, in extract(input_dir, output_dir, backend)
#      12 case "modal":
#      13     logger.info("Running plextract remotely on modal...")
# ---> 14     from .modal import run_pipeline
#      16     run_pipeline.remote(
#      17         input_dir,
#      18         output_dir
#      19     )
#      20 case _:
#
# File ~/extract-line-chart-data/src/plextract/modal/__init__.py:1
# ----> 1 from .app import run_pipeline
#       3 __all__ = ['run_pipeline']
#
# File ~/extract-line-chart-data/src/plextract/modal/app.py:6
#       3 from .modal import vol, app
#       4 from ..utils import correct_coordinates
# ----> 6 from .chartdete import ChartDete
#       7 from .lineformer import LineFormer
#       8 from .trocr import OCRModel
#
# File ~/extract-line-chart-data/src/plextract/modal/chartdete/__init__.py:1
# ----> 1 from .chartdete import ChartDete
#       3 __all__ = ["ChartDete"]
#
# File ~/extract-line-chart-data/src/plextract/modal/chartdete/chartdete.py:17
#      14 import modal
#      15 from modal import App, method
# ---> 17 from .modal import base_cv_image, vol, app
#      19 chardete_image = base_cv_image.run_commands(
#      20     "git clone https://github.com/tdsone/ChartDete"
#      21 ).run_commands("pip install -e ChartDete")
#      24 @app.cls(
#      25     image=chardete_image,
#      26     timeout=3000,
#    (...)     29 )
#      30 class ChartDete:
#
# ModuleNotFoundError: No module named 'plextract.modal.chartdete.modal'
